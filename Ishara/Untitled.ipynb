# %%
import definitions as SA
from iminuit import Minuit

print(SA.Dat1)
# Out:
# Data/HERMES_p_2009.csv

# %%
m = Minuit(SV.totalchi2Minuit,m1=SV.M1_test,Nu=SV.NU_test,alphau=SV.AlphaU_test,betau=SV.BetaU_test,Nubar=SV.NUbar_test,Nd=SV.ND_test,alphad=SV.AlphaD_test,betad=SV.BetaD_test,Ndbar=SV.NDbar_test,Ns=SV.NS_test,alphas=SV.AlphaS_test,betas=SV.BetaS_test,Nsbar=SV.NSbar_test)
m.migrad()
# Out:
# <ipython-input-10-413a44d4a332>:2: IMinuitWarning: errordef not set, using 1 (appropriate for least-squares)
#   m.migrad()
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 130.1                      │             Nfcn = 2353              │
# │ EDM = 0.0858 (Goal: 0.0002)      │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │        No Parameters at limit        │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ...
